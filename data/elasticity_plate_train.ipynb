# %% [markdown]
# Generate FEM solution for 2D Elasticity problem
#
# * Generate Dirichlet/Neumann boundary conditions randomly for four different edges
# * Create multiple data points

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import h5py

import fea.gaussian_random_fields as gr
from fea.fea2d_mesh import SquareMeshElastic
from fea.fea2d_elasticity import ElasticFEM2D
from fea.img_process import project_input
from fea.boundary import define_boundary_nodes

# %%
n = 2**5
mode = 'plane_stress'
ntrain_data = 200
train_file = "data_elasticity/dirich_plate_train_33x33.h5" 
# train_file = "data_elasticity/neumann_plate_train_33x33.h5"
ntest_data = 50
test_file = "data_elasticity/dirich_plate_test_33x33.h5"
# test_file = "data_elasticity/neumann_plate_test_33x33.h5"

# %% [markdown]
# Define the domain

# %%
def plot_image(img):
    plt.figure()
    im1 = plt.imshow(img, origin='lower')
    plt.axis('off')
    plt.colorbar(im1)
    
imarray = np.ones((n,n))
plot_image(imarray)

# %% [markdown]
# Define the loading

# %%
def loading_type1(node_mask, bc):
    '''
    boundary node list: [top, bottom, left, right, curved]

    Randomly assign loadings at boundaries
    ''' 

    h, w = node_mask.shape
    top_idx = np.where(bc[0][0] == 1)
    bottom_idx = np.where(bc[1][0] == 1)
    left_idx = np.where(bc[2][0] == 1)
    right_idx = np.where(bc[3][0] == 1)
    #curved_idx = np.where(bc[4][0] == 1)

    dirich_idx = np.zeros((h, w, 2), dtype=np.int32)
    dirich_value = np.zeros_like(dirich_idx, dtype=np.float32)

    nneumann = 2 # number of neumann boundaries is 2
    neumann_idx = np.zeros((h, w, 2*nneumann), dtype=np.int32)
    neumann_value = np.zeros_like(neumann_idx, dtype=np.float32)
    neumann_connlist = []

    # # randomly pickup neumann boundaries
    # lst = [0, 1, 2, 3]
    # sample_size = nneumann # randomly pick up 2 boundaries as neumann
    # neumann_bc = random.sample(lst, sample_size)
    # bc_list = [i in neumann_bc for i in range(len(lst))]

    # # assign neumann boundaries
    # k = 0
    # for i, is_neumann in enumerate(bc_list):
    #     if(is_neumann):
    #         if(i == 0):
    #             neumann_connlist.append(bc[i][1])
    #             neumann_idx[top_idx[0], top_idx[1], k] = 1 
    #             neumann_value[top_idx[0], top_idx[1], k] = random.uniform(0,1) #random.uniform(-200,200) # [-200,200]
    #         if(i == 1):
    #             neumann_connlist.append(bc[i][1])
    #             neumann_idx[bottom_idx[0], bottom_idx[1], k] = 1 
    #             neumann_value[bottom_idx[0], bottom_idx[1], k] = random.uniform(0,1) #random.uniform(-200,200) # [-200,200]
    #         if(i == 2):
    #             neumann_connlist.append(bc[i][1])
    #             neumann_idx[left_idx[0], left_idx[1], k] = 1 
    #             neumann_value[left_idx[0], left_idx[1], k] = random.uniform(0,1) #random.uniform(-200,200) # [-200,200]
    #         if(i == 3):
    #             neumann_connlist.append(bc[i][1])
    #             neumann_idx[right_idx[0], right_idx[1], k] = 1 
    #             neumann_value[right_idx[0], right_idx[1], k] = random.uniform(0,1) #random.uniform(-200,200) # [-200,200]
    #         k += 1

    bc_list = [False, False, False, False]
    neumann_connlist = [[], []]
    for i, is_neumann in enumerate(bc_list):
        if (not is_neumann):
            if(i == 0):
                dirich_idx[top_idx[0], top_idx[1], 0] = 1 # top
                dirich_idx[top_idx[0], top_idx[1], 1] = 1
                dirich_value[top_idx[0], top_idx[1], 0] = random.uniform(-1,1) 
                dirich_value[top_idx[0], top_idx[1], 1] = random.uniform(-1,1) 
            if(i == 1):
                dirich_idx[bottom_idx[0], bottom_idx[1], 0] = 1 # bottom
                dirich_idx[bottom_idx[0], bottom_idx[1], 1] = 1
                dirich_value[bottom_idx[0], bottom_idx[1], 0] = random.uniform(-1,1) 
                dirich_value[bottom_idx[0], bottom_idx[1], 1] = random.uniform(-1,1) 
            if(i == 2):
                dirich_idx[left_idx[0], left_idx[1], 0] = 1 # left
                dirich_idx[left_idx[0], left_idx[1], 1] = 1
                dirich_value[left_idx[0], left_idx[1], 0] = random.uniform(-1,1) 
                dirich_value[left_idx[0], left_idx[1], 1] = random.uniform(-1,1) 
            if(i == 3):
                dirich_idx[right_idx[0], right_idx[1], 0] = 1 # right
                dirich_idx[right_idx[0], right_idx[1], 1] = 1 
                dirich_value[right_idx[0], right_idx[1], 0] = random.uniform(-1,1) 
                dirich_value[right_idx[0], right_idx[1], 1] = random.uniform(-1,1) 

    dirich_idx_feanet = np.logical_not(dirich_idx).astype(int)
    dirich_idx_feanet *= node_mask.reshape((h, w, 1))

    return dirich_idx, dirich_idx_feanet, dirich_value, neumann_idx, neumann_value, neumann_connlist

# %% [markdown]
# Define the problem

# %%
hsize = 0.2
elem_mask = np.copy(imarray)
h, w = elem_mask.shape
material = np.ones((h, w, 2))
material[:,:,0] = 1
material[:,:,1] = 0.3
node_mask = project_input(elem_mask)

# %%
# define boundary nodes and connections
bc = define_boundary_nodes(elem_mask) # top(0), bottom(1), left(2), right(3), curved(4)
dirich_idx, dirich_idx_feanet, dirich_val, neumann_idx, neumann_val, neumann_connlist = loading_type1(node_mask, bc)

# %%
f_val = np.zeros_like(dirich_val)
# plt.imshow(f_val, origin='lower')
# plt.axis('off')
# plt.colorbar()
# plt.savefig('thermal_source.png', dpi=500, bbox_inches='tight')

# %%
# generate a mesh grid
mesh = SquareMeshElastic(hsize, elem_mask, dirich_idx, neumann_connlist, outfile = None)

# %%
# generate FEM problem
problem = ElasticFEM2D(mesh, 'plane_stress', material, dirich_val, neumann_val, f_val)

# %%
problem.Solve('direct')
problem.PlotField(2)

# %%
# plt.imshow(problem.d.reshape(n+1,n+1), origin='lower')
# plt.axis('off')
# plt.colorbar()
# plt.savefig('thermal_solution.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# Create dataset

# %%
def conn_list2array(node_mask, conn_list):
    '''Convert a connection list into nparrays '''
    h, w = node_mask.shape
    conn_array = np.zeros((h,w,len(conn_list)))
    # print(len(conn_list))
    if(conn_list == [[],[]]):
        return -np.ones((h,w,len(conn_list)))
    
    for i in range(len(conn_list)):
        conn_len = conn_list[i].shape[0]
        subarray = np.full((h*w),-1) 
        subarray[:conn_len] = conn_list[i][:,0]
        subarray[conn_len] = conn_list[i][-1,1]
        conn_array[:,:,i] = subarray.reshape((h,w))
    return conn_array

# %%
def create_dataset(n_data, hsize, n, node_mask, elem_mask, bc, datafile):
    dataset = {}
    dirich_idx_data = np.zeros((n_data, n+1, n+1, 2))
    dirich_value_data = np.zeros((n_data, n+1, n+1, 2))
    neumann_idx_data = np.zeros((n_data, n+1, n+1, 4))
    neumann_conn_data = np.zeros((n_data, n+1, n+1, 2)) 
    neumann_value_data = np.zeros((n_data, n+1, n+1, 4)) # elastic problem will be 4
    node_mask_data = np.zeros((n_data, h+1, w+1, 1))
    elem_mask_data = np.zeros((n_data, h, w, 1))
    material_data = np.zeros((n_data, h, w, 2))
    f_data = np.zeros((n_data, h+1, w+1, 2))
    u_data = np.zeros((n_data, h+1, w+1, 2))
    for i in range(n_data):
        dirich_idx, dirich_idx_feanet, dirich_val, neumann_idx, neumann_val, neumann_connlist = loading_type1(node_mask, bc) # randomly generate bcs
        f_val[:,:,0] = gr.generate_rf(n+1, [-1,1], [0,2]) 
        f_val[:,:,1] = gr.generate_rf(n+1, [-1,1], [0,2]) 
        mesh = SquareMeshElastic(hsize, elem_mask, dirich_idx, neumann_connlist)
        problem = ElasticFEM2D(mesh, mode, material, dirich_val, neumann_val, f_val)      
        problem.Solve()
        material_data[i] = material*elem_mask.reshape((n,n,1))
        elem_mask_data[i,:,:,0] = elem_mask
        dirich_idx_data[i] = dirich_idx_feanet
        dirich_value_data[i] = dirich_val
        neumann_idx_data[i] = neumann_idx
        neumann_value_data[i] = neumann_val
        neumann_conn_data[i] = conn_list2array(node_mask, neumann_connlist)
        f_data[i] = f_val
        u_data[i] = problem.d.reshape((n+1, n+1, 2))
        print("Problem #-"+str(i)+" solved")

        # create mask images
        temp = np.zeros(((n+1)*(n+1),))
        temp[mesh.valid_node] = 1
        node_mask_data[i] = temp.reshape((n+1,n+1,1))
    
    dataset['elem_mask'] = elem_mask_data
    dataset['node_mask'] = node_mask_data
    dataset['dirich_idx'] = dirich_idx_data
    dataset['dirich_value'] = dirich_value_data
    dataset['neumann_idx'] = neumann_idx_data
    dataset['neumann_value'] = neumann_value_data
    dataset['neumann_conn'] = neumann_conn_data
    dataset['material'] = material_data
    dataset['source'] = f_data
    dataset['solution'] = u_data

    with h5py.File(datafile, "w") as hf:
        for key, item in dataset.items():
            hf[key] = item
    #return dataset

# %%
create_dataset(ntest_data, hsize, n, node_mask, elem_mask, bc, test_file)
# Out:
# Problem #-0 solved
# Problem #-1 solved
# Problem #-2 solved
# Problem #-3 solved
# Problem #-4 solved
# Problem #-5 solved
# Problem #-6 solved
# Problem #-7 solved
# Problem #-8 solved
# Problem #-9 solved
# Problem #-10 solved
# Problem #-11 solved
# Problem #-12 solved
# Problem #-13 solved
# Problem #-14 solved
# Problem #-15 solved
# Problem #-16 solved
# Problem #-17 solved
# Problem #-18 solved
# Problem #-19 solved
# Problem #-20 solved
# Problem #-21 solved
# Problem #-22 solved
# Problem #-23 solved
# Problem #-24 solved
# Problem #-25 solved
# Problem #-26 solved
# Problem #-27 solved
# Problem #-28 solved
# Problem #-29 solved
# Problem #-30 solved
# Problem #-31 solved
# Problem #-32 solved
# Problem #-33 solved
# Problem #-34 solved
# Problem #-35 solved
# Problem #-36 solved
# Problem #-37 solved
# Problem #-38 solved
# Problem #-39 solved
# Problem #-40 solved
# Problem #-41 solved
# Problem #-42 solved
# Problem #-43 solved
# Problem #-44 solved
# Problem #-45 solved
# Problem #-46 solved
# Problem #-47 solved
# Problem #-48 solved
# Problem #-49 solved

# %%
create_dataset(ntrain_data, hsize, n, node_mask, elem_mask, bc, train_file)
# Out:
# Problem #-0 solved
# Problem #-1 solved
# Problem #-2 solved
# Problem #-3 solved
# Problem #-4 solved
# Problem #-5 solved
# Problem #-6 solved
# Problem #-7 solved
# Problem #-8 solved
# Problem #-9 solved
# Problem #-10 solved
# Problem #-11 solved
# Problem #-12 solved
# Problem #-13 solved
# Problem #-14 solved
# Problem #-15 solved
# Problem #-16 solved
# Problem #-17 solved
# Problem #-18 solved
# Problem #-19 solved
# Problem #-20 solved
# Problem #-21 solved
# Problem #-22 solved
# Problem #-23 solved
# Problem #-24 solved
# Problem #-25 solved
# Problem #-26 solved
# Problem #-27 solved
# Problem #-28 solved
# Problem #-29 solved
# Problem #-30 solved
# Problem #-31 solved
# Problem #-32 solved
# Problem #-33 solved
# Problem #-34 solved
# Problem #-35 solved
# Problem #-36 solved
# Problem #-37 solved
# Problem #-38 solved
# Problem #-39 solved
# Problem #-40 solved
# Problem #-41 solved
# Problem #-42 solved
# Problem #-43 solved
# Problem #-44 solved
# Problem #-45 solved
# Problem #-46 solved
# Problem #-47 solved
# Problem #-48 solved
# Problem #-49 solved
# Problem #-50 solved
# Problem #-51 solved
# Problem #-52 solved
# Problem #-53 solved
# Problem #-54 solved
# Problem #-55 solved
# Problem #-56 solved
# Problem #-57 solved
# Problem #-58 solved
# Problem #-59 solved
# Problem #-60 solved
# Problem #-61 solved
# Problem #-62 solved
# Problem #-63 solved
# Problem #-64 solved
# Problem #-65 solved
# Problem #-66 solved
# Problem #-67 solved
# Problem #-68 solved
# Problem #-69 solved
# Problem #-70 solved
# Problem #-71 solved
# Problem #-72 solved
# Problem #-73 solved
# Problem #-74 solved
# Problem #-75 solved
# Problem #-76 solved
# Problem #-77 solved
# Problem #-78 solved
# Problem #-79 solved
# Problem #-80 solved
# Problem #-81 solved
# Problem #-82 solved
# Problem #-83 solved
# Problem #-84 solved
# Problem #-85 solved
# Problem #-86 solved
# Problem #-87 solved
# Problem #-88 solved
# Problem #-89 solved
# Problem #-90 solved
# Problem #-91 solved
# Problem #-92 solved
# Problem #-93 solved
# Problem #-94 solved
# Problem #-95 solved
# Problem #-96 solved
# Problem #-97 solved
# Problem #-98 solved
# Problem #-99 solved
# Problem #-100 solved
# Problem #-101 solved
# Problem #-102 solved
# Problem #-103 solved
# Problem #-104 solved
# Problem #-105 solved
# Problem #-106 solved
# Problem #-107 solved
# Problem #-108 solved
# Problem #-109 solved
# Problem #-110 solved
# Problem #-111 solved
# Problem #-112 solved
# Problem #-113 solved
# Problem #-114 solved
# Problem #-115 solved
# Problem #-116 solved
# Problem #-117 solved
# Problem #-118 solved
# Problem #-119 solved
# Problem #-120 solved
# Problem #-121 solved
# Problem #-122 solved
# Problem #-123 solved
# Problem #-124 solved
# Problem #-125 solved
# Problem #-126 solved
# Problem #-127 solved
# Problem #-128 solved
# Problem #-129 solved
# Problem #-130 solved
# Problem #-131 solved
# Problem #-132 solved
# Problem #-133 solved
# Problem #-134 solved
# Problem #-135 solved
# Problem #-136 solved
# Problem #-137 solved
# Problem #-138 solved
# Problem #-139 solved
# Problem #-140 solved
# Problem #-141 solved
# Problem #-142 solved
# Problem #-143 solved
# Problem #-144 solved
# Problem #-145 solved
# Problem #-146 solved
# Problem #-147 solved
# Problem #-148 solved
# Problem #-149 solved
# Problem #-150 solved
# Problem #-151 solved
# Problem #-152 solved
# Problem #-153 solved
# Problem #-154 solved
# Problem #-155 solved
# Problem #-156 solved
# Problem #-157 solved
# Problem #-158 solved
# Problem #-159 solved
# Problem #-160 solved
# Problem #-161 solved
# Problem #-162 solved
# Problem #-163 solved
# Problem #-164 solved
# Problem #-165 solved
# Problem #-166 solved
# Problem #-167 solved
# Problem #-168 solved
# Problem #-169 solved
# Problem #-170 solved
# Problem #-171 solved
# Problem #-172 solved
# Problem #-173 solved
# Problem #-174 solved
# Problem #-175 solved
# Problem #-176 solved
# Problem #-177 solved
# Problem #-178 solved
# Problem #-179 solved
# Problem #-180 solved
# Problem #-181 solved
# Problem #-182 solved
# Problem #-183 solved
# Problem #-184 solved
# Problem #-185 solved
# Problem #-186 solved
# Problem #-187 solved
# Problem #-188 solved
# Problem #-189 solved
# Problem #-190 solved
# Problem #-191 solved
# Problem #-192 solved
# Problem #-193 solved
# Problem #-194 solved
# Problem #-195 solved
# Problem #-196 solved
# Problem #-197 solved
# Problem #-198 solved
# Problem #-199 solved
